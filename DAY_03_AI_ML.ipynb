# %% [markdown]
# **DAY 03**

# %% [markdown]
# **Bar Chart**

# %%
#Matplotlib Bar Chart
import matplotlib.pyplot as plt

students=["Ankita","Mayank","Ayanika","Sayantan"]
marks=[98,80,60,75]

plt.figure(figsize=(8,5))
plt.bar(students,marks,color="purple")
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# **Line Chart**

# %%
#line chart
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
sales=[200,250,300,280,350]
plt.figure(figsize=(8,5))
plt.plot(days,sales,marker="o",color="purple")
plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# **Histogram**

# %%
#Histogram
import matplotlib.pyplot as plt
marks=[95,98,90,80,85,60,87,85,96,75]
plt.figure(figsize=(8,5))
plt.hist(marks,bins=5,edgecolor="Purple")
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Seaborn Count Plot**

# %%
#Seaborn Count Plot
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.DataFrame({
    "Department":["AI","AI","ML","DS","DS","AI","ML"],
})
plt.figure(figsize=(8,5))
sns.countplot(x="Department",data=data,color="purple")
plt.title("Department Count")
plt.show()

# %% [markdown]
# **Seaborn Heatmap**

# %%
#Seaborn Heatmap
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.DataFrame({
    "Marks":[80,85,90,95],
    "Attendance":[90,95,80,85],
    "StudyHours":[3,5,2,4]
})
plt.figure(figsize=(8,5))
sns.heatmap(data.corr(),annot=True,cmap="Purples")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **PANDAS**

# %%
#PANDAS BASICS
import pandas as pd
data={
    "Name":["Ankita","Mayank","Ayanika","Sayantan"],
    "Marks":[98,80,60,75]
}
df=pd.DataFrame(data)
print(df)
print("\nMarks Column:\n")
print(df["Marks"])
# Out:
#        Name  Marks
# 0    Ankita     98
# 1    Mayank     80
# 2   Ayanika     60
# 3  Sayantan     75
#
# Marks Column:
#
# 0    98
# 1    80
# 2    60
# 3    75
# Name: Marks, dtype: int64

# %% [markdown]
# **PROJECT 04**

# %% [markdown]
# **STUDENT PERFORMANCE DATA ANALYSIS**

# %%
#STEP 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#optional display setting
pd.set_option("display.max_columns",None)

# %%
#STEP 2: Data Collection
#Creating a sample student dataset
data={
    "Student_ID":[101,102,103,104,105,106,107,108],
    "Name":["Ankita","Mayank","Ayanika","Sayantan","Soumili","Akalpita","Anindita","Kajal"],
    "Gender":["Female","Male","Female","Male","Female","Female","Female","Male"],
    "Math":[85,92,78,np.nan,88,76,95,67],
    "Science":[90,89,np.nan,72,88,80,98,70],
    "English":[88,94,79,np.nan,82,96,68,np.nan], # Added np.nan to match length
    "Attendance":[92,96,85,78,88,80,98,np.nan],
    "Study_Hours":[3.5,5.0,2.5,2.0,4.0,3.0,6.0,1.5]
}
df=pd.DataFrame(data)
print("=======ORIGINAL DATASET=======")
print(df)
# Out:
# =======ORIGINAL DATASET=======
#    Student_ID      Name  Gender  Math  Science  English  Attendance  \
# 0         101    Ankita  Female  85.0     90.0     88.0        92.0
# 1         102    Mayank    Male  92.0     89.0     94.0        96.0
# 2         103   Ayanika  Female  78.0      NaN     79.0        85.0
# 3         104  Sayantan    Male   NaN     72.0      NaN        78.0
# 4         105   Soumili  Female  88.0     88.0     82.0        88.0
# 5         106  Akalpita  Female  76.0     80.0     96.0        80.0
# 6         107  Anindita  Female  95.0     98.0     68.0        98.0
# 7         108     Kajal    Male  67.0     70.0      NaN         NaN
#
#    Study_Hours
# 0          3.5
# 1          5.0
# 2          2.5
# 3          2.0
# 4          4.0
# 5          3.0
# 6          6.0
# 7          1.5

# %%
#STEP 3: basic information
#=========================
print("\n=======DATASET INFO======")
print(df.info())
print("\n=======FIRST 5 ROWS======")
print(df.head())
print("\n=======LAST 5 ROWS======")
print(df.tail())
print("\n=======SHAPE OF DATASET======")
print(df.shape)
print("\n=======COLUMN NAMES======")
print(df.columns)
# Out:
# =======DATASET INFO======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_ID   8 non-null      int64
#  1   Name         8 non-null      object
#  2   Gender       8 non-null      object
#  3   Math         7 non-null      float64
#  4   Science      7 non-null      float64
#  5   English      6 non-null      float64
#  6   Attendance   7 non-null      float64
#  7   Study_Hours  8 non-null      float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 644.0+ bytes
# None
#
# =======FIRST 5 ROWS======
#    Student_ID      Name  Gender  Math  Science  English  Attendance  \
# 0         101    Ankita  Female  85.0     90.0     88.0        92.0
# 1         102    Mayank    Male  92.0     89.0     94.0        96.0
# 2         103   Ayanika  Female  78.0      NaN     79.0        85.0
# 3         104  Sayantan    Male   NaN     72.0      NaN        78.0
# 4         105   Soumili  Female  88.0     88.0     82.0        88.0
#
#    Study_Hours
# 0          3.5
# 1          5.0
# 2          2.5
# 3          2.0
# 4          4.0
#
# =======LAST 5 ROWS======
#    Student_ID      Name  Gender  Math  Science  English  Attendance  \
# 3         104  Sayantan    Male   NaN     72.0      NaN        78.0
# 4         105   Soumili  Female  88.0     88.0     82.0        88.0
# 5         106  Akalpita  Female  76.0     80.0     96.0        80.0
# 6         107  Anindita  Female  95.0     98.0     68.0        98.0
# 7         108     Kajal    Male  67.0     70.0      NaN         NaN
#
#    Study_Hours
# 3          2.0
# 4          4.0
# 5          3.0
# 6          6.0
# 7          1.5
#
# =======SHAPE OF DATASET======
# (8, 8)
#
# =======COLUMN NAMES======
# Index(['Student_ID', 'Name', 'Gender', 'Math', 'Science', 'English',
#        'Attendance', 'Study_Hours'],
#       dtype='object')

# %%
#STEP 4: chack missing values
print("\n=======MISSING VALUES======")
print(df.isnull().sum())
# Out:
# =======MISSING VALUES======
# Student_ID     0
# Name           0
# Gender         0
# Math           0
# Science        0
# English        0
# Attendance     0
# Study_Hours    0
# dtype: int64

# %%
#STEP 5:data processing
# filling missing numeric values with column mean
df["Math"].fillna(df["Math"].mean(),inplace=True)
df["Science"].fillna(df["Science"].mean(),inplace=True)
df["English"].fillna(df["English"].mean(),inplace=True)
df["Attendance"].fillna(df["Attendance"].mean(),inplace=True)
print("\n=======DATASET AFTER MISSING VALUES======")
print(df.isnull().sum())
print("\n=======MISSING VALUES AFTER PROCESSING======")
print(df.isnull().sum())
# Out:
# =======DATASET AFTER MISSING VALUES======
# Student_ID     0
# Name           0
# Gender         0
# Math           0
# Science        0
# English        0
# Attendance     0
# Study_Hours    0
# dtype: int64
#
# =======MISSING VALUES AFTER PROCESSING======
# Student_ID     0
# Name           0
# Gender         0
# Math           0
# Science        0
# English        0
# Attendance     0
# Study_Hours    0
# dtype: int64
# /tmp/ipykernel_5525/3389786755.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Math"].fillna(df["Math"].mean(),inplace=True)
# /tmp/ipykernel_5525/3389786755.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Science"].fillna(df["Science"].mean(),inplace=True)
# /tmp/ipykernel_5525/3389786755.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["English"].fillna(df["English"].mean(),inplace=True)
# /tmp/ipykernel_5525/3389786755.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Attendance"].fillna(df["Attendance"].mean(),inplace=True)

# %%
#STEP 6: add new columns
#=======================
df["Total"]=df["Math"]+df["Science"]+df["English"]
df["Average"]=df["Total"]/3
#Grade Calculation
def assign_grade(avg):
    if avg>=90:
        return "A+"
    elif avg>=80:
        return "A"
    elif avg>=70:
        return "B"
    elif avg>=60:
        return "C"
    else:
        return "D"
df["Grade"]=df["Average"].apply(assign_grade)
print("\n=========DATASET WITH TOTAL,AVERAGE,GRADE=========")
print(df)
# Out:
# =========DATASET WITH TOTAL,AVERAGE,GRADE=========
#    Student_ID      Name  Gender  Math    Science  English  Attendance  \
# 0         101    Ankita  Female  85.0  90.000000     88.0   92.000000
# 1         102    Mayank    Male  92.0  89.000000     94.0   96.000000
# 2         103   Ayanika  Female  78.0  83.857143     79.0   85.000000
# 3         104  Sayantan    Male  83.0  72.000000     84.5   78.000000
# 4         105   Soumili  Female  88.0  88.000000     82.0   88.000000
# 5         106  Akalpita  Female  76.0  80.000000     96.0   80.000000
# 6         107  Anindita  Female  95.0  98.000000     68.0   98.000000
# 7         108     Kajal    Male  67.0  70.000000     84.5   88.142857
#
#    Study_Hours       Total    Average Grade
# 0          3.5  263.000000  87.666667     A
# 1          5.0  275.000000  91.666667    A+
# 2          2.5  240.857143  80.285714     A
# 3          2.0  239.500000  79.833333     B
# 4          4.0  258.000000  86.000000     A
# 5          3.0  252.000000  84.000000     A
# 6          6.0  261.000000  87.000000     A
# 7          1.5  221.500000  73.833333     B

# %%
# Step 7: Descriptive Statistics
# ================================
print("\n========== DESCRIPTIVE STATISTICS ==========")
print(df.describe())
# Out:
# ========== DESCRIPTIVE STATISTICS ==========
#        Student_ID       Math    Science    English  Attendance  Study_Hours  \
# count     8.00000   8.000000   8.000000   8.000000    8.000000     8.000000
# mean    104.50000  83.000000  83.857143  84.500000   88.142857     3.437500
# std       2.44949   9.133924   9.478224   8.811518    7.099871     1.522158
# min     101.00000  67.000000  70.000000  68.000000   78.000000     1.500000
# 25%     102.75000  77.500000  78.000000  81.250000   83.750000     2.375000
# 50%     104.50000  84.000000  85.928571  84.500000   88.071429     3.250000
# 75%     106.25000  89.000000  89.250000  89.500000   93.000000     4.250000
# max     108.00000  95.000000  98.000000  96.000000   98.000000     6.000000
#
#             Total    Average
# count    8.000000   8.000000
# mean   251.357143  83.785714
# std     16.794375   5.598125
# min    221.500000  73.833333
# 25%    240.517857  80.172619
# 50%    255.000000  85.000000
# 75%    261.500000  87.166667
# max    275.000000  91.666667

# %%
# Step 8: Top Performer

topper = df.loc[df["Average"].idxmax()]

print("\n========== TOPPER STUDENT ==========")
print("Name:", topper["Name"])
print("Average Marks:", round(topper["Average"], 2))
print("Grade:", topper["Grade"])
# Out:
# ========== TOPPER STUDENT ==========
# Name: Mayank
# Average Marks: 91.67
# Grade: A+

# %%
# Step 9: Students with High Attendance

high_attendance = df[df["Attendance"] > 90]

print("\n========== STUDENTS WITH ATTENDANCE > 90 ==========")
print(high_attendance[["Name", "Attendance"]])
# Out:
# ========== STUDENTS WITH ATTENDANCE > 90 ==========
#        Name  Attendance
# 0    Ankita        92.0
# 1    Mayank        96.0
# 6  Anindita        98.0

# %%
# Step 10: Students with Average > 80
# ================================
high_performers = df[df["Average"] > 80]

print("\n========== STUDENTS WITH AVERAGE > 80 ==========")
print(high_performers[["Name", "Average", "Grade"]])
# Out:
# ========== STUDENTS WITH AVERAGE > 80 ==========
#        Name    Average Grade
# 0    Ankita  87.666667     A
# 1    Mayank  91.666667    A+
# 2   Ayanika  80.285714     A
# 4   Soumili  86.000000     A
# 5  Akalpita  84.000000     A
# 6  Anindita  87.000000     A

# %%
# Step 11: Group By Gender
# ================================
gender_avg = df.groupby("Gender")[["Math", "Science", "English", "Average"]].mean()

print("\n========== AVERAGE MARKS BY GENDER ==========")
print(gender_avg)
# Out:
# ========== AVERAGE MARKS BY GENDER ==========
#              Math    Science    English    Average
# Gender
# Female  84.400000  87.971429  82.600000  84.990476
# Male    80.666667  77.000000  87.666667  81.777778

# %%
# Step 12: Sorting
# ================================
sorted_df = df.sort_values(by="Average", ascending=False)

print("\n========== STUDENTS SORTED BY AVERAGE MARKS ==========")
print(sorted_df[["Name", "Average", "Grade"]])
# Out:
# ========== STUDENTS SORTED BY AVERAGE MARKS ==========
#        Name    Average Grade
# 1    Mayank  91.666667    A+
# 0    Ankita  87.666667     A
# 6  Anindita  87.000000     A
# 4   Soumili  86.000000     A
# 5  Akalpita  84.000000     A
# 2   Ayanika  80.285714     A
# 3  Sayantan  79.833333     B
# 7     Kajal  73.833333     B

# %%
# Step 13: Visualization - Bar Chart
# ================================
plt.figure(figsize=(10, 5))
plt.bar(df["Name"], df["Average"])
plt.title("Student Average Marks")
plt.xlabel("Student Name")
plt.ylabel("Average Marks")
plt.xticks(rotation=45)
plt.show()

# %%
# Step 14: Visualization - Line Chart
# ================================
plt.figure(figsize=(10, 5))
plt.plot(df["Name"], df["Attendance"], marker='o')
plt.title("Student Attendance")
plt.xlabel("Student Name")
plt.ylabel("Attendance")
plt.xticks(rotation=45)
plt.show()

# %%
# Step 15: Visualization - Histogram
# ================================
plt.figure(figsize=(8, 5))
plt.hist(df["Average"], bins=5, edgecolor="black")
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Frequency")
plt.show()

# %%
# Step 16: Visualization - Pie Chart
# ================================
grade_counts = df["Grade"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(grade_counts, labels=grade_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Grade Distribution")
plt.show()

# %%
# Step 17: Seaborn Count Plot
# ================================
plt.figure(figsize=(8, 5))
sns.countplot(x="Grade", data=df)
plt.title("Count of Students by Grade")
plt.show()

# %%
# Step 18: Seaborn Box Plot
# ================================
plt.figure(figsize=(8, 5))
sns.boxplot(x="Gender", y="Average", data=df)
plt.title("Average Marks by Gender")
plt.show()

# %%
# Step 19: Seaborn Scatter Plot
# ================================
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Study_Hours", y="Average", hue="Gender", data=df, s=100)
plt.title("Study Hours vs Average Marks")
plt.show()

# %%
# Step 20: Correlation Heatmap
# ================================
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Step 21: Save Cleaned Dataset
# ================================
df.to_csv("cleaned_student_performance.csv", index=False)
print("\nCleaned dataset saved as 'cleaned_student_performance.csv'")
# Out:
# Cleaned dataset saved as 'cleaned_student_performance.csv'

# %%
# Step 22: Final Output
# ================================
print("\n========== FINAL CLEANED DATASET ==========")
print(df)
# Out:
# ========== FINAL CLEANED DATASET ==========
#    Student_ID      Name  Gender  Math    Science  English  Attendance  \
# 0         101    Ankita  Female  85.0  90.000000     88.0   92.000000
# 1         102    Mayank    Male  92.0  89.000000     94.0   96.000000
# 2         103   Ayanika  Female  78.0  83.857143     79.0   85.000000
# 3         104  Sayantan    Male  83.0  72.000000     84.5   78.000000
# 4         105   Soumili  Female  88.0  88.000000     82.0   88.000000
# 5         106  Akalpita  Female  76.0  80.000000     96.0   80.000000
# 6         107  Anindita  Female  95.0  98.000000     68.0   98.000000
# 7         108     Kajal    Male  67.0  70.000000     84.5   88.142857
#
#    Study_Hours       Total    Average Grade
# 0          3.5  263.000000  87.666667     A
# 1          5.0  275.000000  91.666667    A+
# 2          2.5  240.857143  80.285714     A
# 3          2.0  239.500000  79.833333     B
# 4          4.0  258.000000  86.000000     A
# 5          3.0  252.000000  84.000000     A
# 6          6.0  261.000000  87.000000     A
# 7          1.5  221.500000  73.833333     B
